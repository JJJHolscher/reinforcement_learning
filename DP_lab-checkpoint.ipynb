# %% [markdown]
# # Reinforcement Learning - Dynamic Programming
# If you want to test/submit your solution **restart the kernel, run all cells and submit the dp_autograde.py file into codegrade.**

# %%
# This cell imports %%execwritefile command (executes cell and writes it into file). 
# All cells that start with %%execwritefile should be in dp_autograde.py file after running all cells.
from custommagics import CustomMagics
get_ipython().register_magics(CustomMagics)

# %%
# %%execwritefile dp_autograde.py
# import numpy as np
# from collections import defaultdict
# Out:
# Overwriting dp_autograde.py

# %%
import matplotlib.pyplot as plt
import sys

# %matplotlib inline

assert sys.version_info[:3] >= (3, 6, 0), "Make sure you have Python 3.6 installed!"

# %% [markdown]
# ## 1. Policy Evaluation (1 point)
# In this exercise we will evaluate a policy, e.g. find the value function of a policy. The problem we consider is the gridworld from Example 4.1 in the book. The environment is implemented as `GridworldEnv`, which is a subclass of the `Env` class from [OpenAI Gym](https://github.com/openai/gym). This means that we can interact with the environment. We can look at the documentation to see how we can interact with the environment.

# %%
from gridworld import GridworldEnv
env = GridworldEnv()
# Lets see what this is
# ?env

# %%
# To have a quick look into the code
??env

# %% [markdown]
# Now we want to evaluate a policy by using Dynamic Programming. For more information, see the [Intro to RL](https://drive.google.com/open?id=1opPSz5AZ_kVa1uWOdOiveNiBFiEOHjkG) book, section 4.1. This algorithm requires knowledge of the problem dynamics in the form of the transition probabilities $p(s',r|s,a)$. In general these are not available, but for our gridworld we know the dynamics and these can be accessed as `env.P`. Note that we do not need to use a discount_factor for episodic tasks but make sure your implementation can handle this correctly!

# %%
# Take a moment to figure out what P represents. 
# Note that this is a deterministic environment. 
# What would a stochastic environment look like?
a = env.P
a[1]
# Out:
# {0: [(1.0, 1, -1.0, False)],
#  1: [(1.0, 2, -1.0, False)],
#  2: [(1.0, 5, -1.0, False)],
#  3: [(1.0, 0, -1.0, True)]}

# %%
# %%execwritefile -a dp_autograde.py
#
# def policy_eval_v(policy, env, discount_factor=1.0, theta=0.00001):
#
#
#     """
#     Evaluate a policy given an environment and a full description of the environment's dynamics.
#
#     Args:
#         policy: [S, A] shaped matrix representing the policy.
#         env: OpenAI env. env.P represents the transition probabilities of the environment.
#             env.P[s][a] is a list of transition tuples (prob, next_state, reward, done).
#             env.nS is a number of states in the environment.
#             env.nA is a number of actions in the environment.
#         theta: We stop evaluation once our value function change is less than theta for all states.
#         discount_factor: Gamma discount factor.
#
#     Returns:
#         Vector of length env.nS representing the value function.
#     """
#     # Start with an all 0 value function
#     V = np.zeros(env.nS)
#
#     # loop door alle states heen
#         # sla de oude state value op
#         # Bereken de nieuwe state value door de SOM (kans omhoog * loop over waar je terrecht kunt komen * reward) kans omlaag..
#     # kijk of je nog door moet gaan of stoppen
#     delta = 1000
# #     while delta > theta:
#     for x in range(2):
#
#         deltas = []
#
# #   loop throw possible states
#         for state in range(env.nS):
#             print(V[14])
#             old_state_value = V[state]
#
#             new_state_value = 0
#
#     #       loop shrow possible actions in state
#             for action in range(env.nA):
#
#                 print("kans omhoog", policy[state][action])
# #                 print("kans omhoog uitkomen", env.P[state][action][0][0])
#                 print("direct reward",env.P[state][action][0][2] )
#                 print("value of that new state", discount_factor * V[env.P[state][action][0][1]] )
#
#                 current_state_value = policy[state][action] * env.P[state][action][0][0] * ( env.P[state][action][0][2] + ( discount_factor * V[env.P[state][action][0][1]] ) )
# #                 print("current state value", current_state_value)
#                 delta = abs(old_state_value - current_state_value)
#                 deltas.append(delta)
#
#                 V[state] += current_state_value
# #                 print(V[state])
#         delta = max(deltas)
# #         print("delta", delta)
#
#     return np.array(V)
# Out:
# Appending to dp_autograde.py

# %%
# Let's run your code, does it make sense?
random_policy = np.ones([env.nS, env.nA]) / env.nA
V = policy_eval_v(random_policy, env)
assert V.shape == (env.nS)
V
# Out:
# 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.0
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -0.25
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.25
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -0.75
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.1875
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.25
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.546875
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -0.59375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.69921875
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.1875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.046875
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.546875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.55859375
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.69921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.7763671875
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.9169921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -0.729248046875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.868896484375
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.55859375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -0.8896484375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.362060546875
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.7763671875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -0.944091796875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.95257568359375
# 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.868896484375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -0.96722412109375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.1682586669921875
# -2.2510948181152344
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# -2.2510948181152344
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.25
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.546875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.25
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.69921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.94921875
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.96875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.9169921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.068359375
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.546875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.55859375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.7138671875
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.94921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.69921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.7763671875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -3.642333984375
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.068359375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.9169921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.868896484375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -5.06365966796875
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.707275390625
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -3.34381103515625
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.1287841796875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -5.9286956787109375
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -3.642333984375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.7763671875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.95257568359375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.1514129638671875
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -5.06365966796875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -1.868896484375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.1682586669921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -5.439266204833984
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -5.9286956787109375
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.1287841796875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -6.4113874435424805
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -6.944133758544922
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.1148176193237305
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -7.048887014389038
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -5.439266204833984
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.1682586669921875
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.354456901550293
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -5.693071126937866
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -6.4113874435424805
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.833879232406616
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -7.366338908672333
# -2.2510948181152344
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -7.048887014389038
# kans omhoog 0.25
# direct reward -1.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -4.513316571712494
# kans omhoog 0.25
# direct reward -1.0
# value of that new state -8.383933767676353
# -8.237629156559706
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# kans omhoog 0.25
# direct reward 0.0
# value of that new state 0.0
# array([ 0.        , -2.94921875, -4.06835938, -4.70727539, -3.64233398,
#        -5.06365967, -5.92869568, -6.94413376, -5.4392662 , -6.41138744,
#        -7.04888701, -7.65574378, -7.36633891, -8.38393377, -8.23762916,
#         0.        ])

# %%
def plot_gridworld_value(V):
    plt.figure()
    c = plt.pcolormesh(V, cmap='gray')
    plt.colorbar(c)
    plt.gca().invert_yaxis()  # In the array, first row = 0 is on top

# Making a plot always helps
plot_gridworld_value(V.reshape(env.shape))

# %% [markdown]
# ---
# ## 2. Policy Iteration (2 points)
# Using the policy evaluation algorithm we can implement policy iteration to find a good policy for this problem. Note that we do not need to use a discount_factor for episodic tasks but make sure your implementation can handle this correctly!

# %%
# %%execwritefile -a dp_autograde.py
#
# def policy_iter_v(env, policy_eval_v=policy_eval_v, discount_factor=1.0):
#     """
#     Policy Iteration Algorithm. Iteratively evaluates and improves a policy
#     until an optimal policy is found.
#
#     Args:
#         env: The OpenAI envrionment.
#         policy_eval_v: Policy Evaluation function that takes 3 arguments:
#             policy, env, discount_factor.
#         discount_factor: gamma discount factor.
#
#     Returns:
#         A tuple (policy, V).
#         policy is the optimal policy, a matrix of shape [S, A] where each state s
#         contains a valid probability distribution over actions.
#         V is the value function for the optimal policy.
#
#     """
#     # Start with a random policy
#     policy = np.ones([env.nS, env.nA]) / env.nA
#     # YOUR CODE HERE
#     raise NotImplementedError
#     return policy, V
# Out:
# Appending to dp_autograde.py

# %%
# Let's see what it does
policy, v = policy_iter_v(env, policy_eval_v)
print("Policy Probability Distribution:")
print(policy)
print("")

def print_grid_policy(policy, symbols=["^", ">", "v", "<"]):
    symbols = np.array(symbols)
    for row in policy:
        print("".join(symbols[row]))

print("Reshaped Grid Policy (0=up, 1=right, 2=down, 3=left):")
print(np.reshape(np.argmax(policy, axis=1), env.shape))
print_grid_policy(np.reshape(np.argmax(policy, axis=1), env.shape))
print("")

print("Value Function:")
print(v)
print("")

print("Reshaped Grid Value Function:")
print(v.reshape(env.shape))
print("")

plot_gridworld_value(v.reshape(env.shape))

# %% [markdown]
# ---
# ## 3. Q-value Iteration (3 points)
# In this exercise you will implement the value iteration algorithm. However, because this algorithm is quite similar to the ones you implemented previously, we will spice things up a bit and use Q-values instead. Thus instead of using Bellman optimality equations for V you will use Bellman equations for Q.

# %%
# %%execwritefile -a dp_autograde.py
#
# def value_iter_q(env, theta=0.0001, discount_factor=1.0):
#     """
#     Q-value Iteration Algorithm.
#
#     Args:
#         env: OpenAI env. env.P represents the transition probabilities of the environment.
#             env.P[s][a] is a list of transition tuples (prob, next_state, reward, done).
#             env.nS is a number of states in the environment.
#             env.nA is a number of actions in the environment.
#         theta: We stop evaluation once our value function change is less than theta for all state-action pairs.
#         discount_factor: Gamma discount factor.
#
#     Returns:
#         A tuple (policy, Q) of the optimal policy and the optimal Q-value function.
#     """
#
#     # Start with an all 0 Q-value function
#     Q = np.zeros((env.nS, env.nA))
#     # YOUR CODE HERE
#     raise NotImplementedError
#     return policy, Q

# %%
# Let's see what it does
policy, Q = value_iter_q(env)
print("Policy Probability Distribution:")
print(policy)
print("")

print("Reshaped Grid Policy (0=up, 1=right, 2=down, 3=left):")
print(np.reshape(np.argmax(policy, axis=1), env.shape))
print_grid_policy(np.reshape(np.argmax(policy, axis=1), env.shape))
print("")

print("Q Function:")
print(Q)
print("")

# %%
# As you can see, the visualization of the Q function is quite clumsy and is not that easy to check 
# that all values make sense. However, you can easily create a V function from Q and policy to double
# check that the values are what you would expect.

# %% [markdown]
# If you want to test/submit your solution **restart the kernel, run all cells and submit the dp_autograde.py file into codegrade.**
